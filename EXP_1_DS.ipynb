# %%
import pandas as pd

# %%
data =  pd.read_csv("Bengaluru_House_Data.csv")

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
print("\nChecking Missing Values:")

print(data.isnull().sum())
# Out:
# Checking Missing Values:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
print("Dimentions of Data Frames:")

print(data.shape)
# Out:
# Dimentions of Data Frames:
# (13320, 9)

# %%
print(data)
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data.fillna("NA",inplace=True)

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft bath balcony   price
# 0          2 BHK  Coomee        1056  2.0     1.0   39.07
# ...

# %%
data["balcony"].replace("NA",0, inplace=True)

data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft bath  balcony   price
# 0          2 BHK  Coomee        1056  2.0      1.0   39.07
# ...

# %%
# Checking again missing values

print(data.isnull().sum())
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
print("Data Types of Varibles:")
print(data.dtypes)
# Out:
# Data Types of Varibles:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath             object
# balcony         float64
# price           float64
# dtype: object

# %%
# Changing the Data Type 

data["area_type"] =data["area_type"].astype("category").cat.codes

# %%
data
# Out:
#        area_type   availability                  location       size  society  \
# 0              3         19-Dec  Electronic City Phase II      2 BHK  Coomee
# 1              2  Ready To Move          Chikka Tirupathi  4 Bedroom  Theanmp
# 2              0  Ready To Move               Uttarahalli      3 BHK       NA
# 3              3  Ready To Move        Lingadheeranahalli      3 BHK  Soiewre
# 4              3  Ready To Move                  Kothanur      2 BHK       NA
# ...          ...            ...                       ...        ...      ...
# 13315          0  Ready To Move                Whitefield  5 Bedroom  ArsiaEx
# 13316          3  Ready To Move             Richards Town      4 BHK       NA
# 13317          0  Ready To Move     Raja Rajeshwari Nagar      2 BHK  Mahla T
# 13318          3         18-Jun           Padmanabhanagar      4 BHK  SollyCl
# 13319          3  Ready To Move              Doddathoguru      1 BHK       NA
#
# ...

# %%
data.dtypes
# Out:
# area_type          int8
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath             object
# balcony         float64
# price           float64
# dtype: object

# %%
data["size"] = data["size"].str.replace("BHK", "Bedroom")

# %%
data
# Out:
#        area_type   availability                  location       size  society  \
# 0              3         19-Dec  Electronic City Phase II  2 Bedroom  Coomee
# 1              2  Ready To Move          Chikka Tirupathi  4 Bedroom  Theanmp
# 2              0  Ready To Move               Uttarahalli  3 Bedroom       NA
# 3              3  Ready To Move        Lingadheeranahalli  3 Bedroom  Soiewre
# 4              3  Ready To Move                  Kothanur  2 Bedroom       NA
# ...          ...            ...                       ...        ...      ...
# 13315          0  Ready To Move                Whitefield  5 Bedroom  ArsiaEx
# 13316          3  Ready To Move             Richards Town  4 Bedroom       NA
# 13317          0  Ready To Move     Raja Rajeshwari Nagar  2 Bedroom  Mahla T
# 13318          3         18-Jun           Padmanabhanagar  4 Bedroom  SollyCl
# 13319          3  Ready To Move              Doddathoguru  1 Bedroom       NA
#
# ...
